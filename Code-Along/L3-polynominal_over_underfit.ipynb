# %% [markdown]
# # Polynomial regression
# - underfit
# - overfit

# %%
import numpy as np
import matplotlib.pyplot as plt

samples = 100
X = np.random.uniform(-3,3, (samples, 1))
f = lambda x: x**2 + .5*x + 3
y = f(X) + np.random.randn(samples, 1)

plt.plot(X, y, ".")

x = np.linspace(-3,3)
plt.plot(x, f(x))
plt.title("Simulated data")
# Out:
# Text(0.5, 1.0, 'Simulated data')

# %% [markdown]
# ## Polynomial regression

# %%
from sklearn.preprocessing import PolynomialFeatures
polynomial_features = PolynomialFeatures(degree = 2, include_bias=False)
poly_X = polynomial_features.fit_transform(X)
poly_X[:3]
# Out:
# array([[-1.95232773,  3.81158356],
#        [ 0.34925969,  0.12198233],
#        [ 0.25109729,  0.06304985]])

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(poly_X, y)
model.coef_
# Out:
# array([[0.49910827, 1.03277899]])

# %%
x = np.linspace(-3,3, samples).reshape(samples, 1)
x_poly_features = polynomial_features.transform(x)
y_pred = model.predict(x_poly_features)
y_pred.shape, x.shape

plt.plot(x, y_pred)
